# %%
from pyzeus import show_zeus as sz
import os
# %matplotlib inline

hdfdir1 = '/home/astrodoo/Work/Data/DataSet/2016_AGNRot/agnRot_ac5_k01/'
hdfdir2 = '/home/astrodoo/Work/Data/DataSet/2016_AGNRot/agnRot_ac5/'
hdfdir3 = '/home/astrodoo/Work/Data/DataSet/2016_AGNRot/agnRot_ac5_k07/'


outdir = os.environ['PYTHONFIG']
sz.show_zeus4f(hdfdir1+'hdfra.300',hdfdir1+'hdfra.500',hdfdir2+'hdfra.500',hdfdir3+'hdfra.500'\
            ,inpfile=hdfdir1+'zmp_inp' \
            , out=outdir+'test.png')
# Out:
# Reading /home/astrodoo/Work/Data/DataSet/2016_AGNRot/agnRot_ac5_k01/hdfra.300 of time = 3.75
# Reading /home/astrodoo/Work/Data/DataSet/2016_AGNRot/agnRot_ac5_k01/hdfra.500 of time = 6.25
# Reading /home/astrodoo/Work/Data/DataSet/2016_AGNRot/agnRot_ac5/hdfra.500 of time = 6.25
# Reading /home/astrodoo/Work/Data/DataSet/2016_AGNRot/agnRot_ac5_k07/hdfra.500 of time = 6.25
# saved to /home/astrodoo/lib/python/figures/test.png

# %%
from pyzeus import hdf4 

hdf4.info(hdfdir+'hdfaa.100')

# %%
import matplotlib.pyplot as plt
fig = plt.figure()

# %%
# ?fig.add_axes
