# %% [markdown]
# # Only axes

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %matplotlib inline

# Setup a plot such that only the bottom spine is shown
def setup(ax):
    ax.spines['right'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.yaxis.set_major_locator(ticker.NullLocator())
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.tick_params(which='major', width=1.00)
    ax.tick_params(which='major', length=5)
    ax.tick_params(which='minor', width=0.75)
    ax.tick_params(which='minor', length=2.5)
    ax.set_xlim(0, 5)
    ax.set_ylim(0, 1)
    ax.patch.set_alpha(0.0)


plt.figure(figsize=(8, 6))
n = 8

# Null Locator
ax = plt.subplot(n, 1, 1)
setup(ax)
ax.xaxis.set_major_locator(ticker.NullLocator())
ax.xaxis.set_minor_locator(ticker.NullLocator())
ax.text(0.0, 0.1, "NullLocator()", fontsize=14, transform=ax.transAxes)

# Multiple Locator
ax = plt.subplot(n, 1, 2)
setup(ax)
ax.xaxis.set_major_locator(ticker.MultipleLocator(0.5))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax.text(0.0, 0.1, "MultipleLocator(0.5)", fontsize=14,
        transform=ax.transAxes)

# Fixed Locator
ax = plt.subplot(n, 1, 3)
setup(ax)
majors = [0, 1, 5]
ax.xaxis.set_major_locator(ticker.FixedLocator(majors))
minors = np.linspace(0, 1, 11)[1:-1]
ax.xaxis.set_minor_locator(ticker.FixedLocator(minors))
ax.text(0.0, 0.1, "FixedLocator([0, 1, 5])", fontsize=14,
        transform=ax.transAxes)

# Linear Locator
ax = plt.subplot(n, 1, 4)
setup(ax)
ax.xaxis.set_major_locator(ticker.LinearLocator(3))
ax.xaxis.set_minor_locator(ticker.LinearLocator(31))
ax.text(0.0, 0.1, "LinearLocator(numticks=3)",
        fontsize=14, transform=ax.transAxes)

# Index Locator
ax = plt.subplot(n, 1, 5)
setup(ax)
ax.plot(range(0, 5), [0]*5, color='White')
ax.xaxis.set_major_locator(ticker.IndexLocator(base=.5, offset=.25))
ax.text(0.0, 0.1, "IndexLocator(base=0.5, offset=0.25)",
        fontsize=14, transform=ax.transAxes)

# Auto Locator
ax = plt.subplot(n, 1, 6)
setup(ax)
ax.xaxis.set_major_locator(ticker.AutoLocator())
ax.xaxis.set_minor_locator(ticker.AutoMinorLocator())
ax.text(0.0, 0.1, "AutoLocator()", fontsize=14, transform=ax.transAxes)

# MaxN Locator
ax = plt.subplot(n, 1, 7)
setup(ax)
ax.xaxis.set_major_locator(ticker.MaxNLocator(4))
ax.xaxis.set_minor_locator(ticker.MaxNLocator(40))
ax.text(0.0, 0.1, "MaxNLocator(n=4)", fontsize=14, transform=ax.transAxes)

# Log Locator
ax = plt.subplot(n, 1, 8)
setup(ax)
ax.set_xlim(10**3, 10**10)
ax.set_xscale('log')
ax.xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=15))
ax.text(0.0, 0.1, "LogLocator(base=10, numticks=15)",
        fontsize=15, transform=ax.transAxes)

# Push the top of the top axes outside the figure because we only show the
# bottom spine.
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.05, top=1.05)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %matplotlib inline

# Setup a plot such that only the bottom spine is shown
def setup(ax):
    ax.spines['top'].set_color('none')
    ax.spines['bottom'].set_color('none')
    ax.xaxis.set_major_locator(ticker.NullLocator())
    ax.spines['left'].set_color('none')
    ax.yaxis.set_ticks_position('right')
    ax.tick_params(which='major', width=1.00)
    ax.tick_params(which='major', length=5)
    ax.tick_params(which='minor', width=0.75)
    ax.tick_params(which='minor', length=2.5)
    ax.set_ylim(0, 5)
    ax.set_xlim(0, 1)
    ax.patch.set_alpha(0.0)


plt.figure(figsize=(8, 6))
n = 8

# Null Locator
ax = plt.subplot(1, n, 1)
setup(ax)
ax.yaxis.set_major_locator(ticker.NullLocator())
ax.yaxis.set_minor_locator(ticker.NullLocator())
ax.text(1.2, 0.5, "NullLocator()", fontsize=14, transform=ax.transAxes, rotation=90,va='center')

# Multiple Locator
ax = plt.subplot(1, n, 2)
setup(ax)
ax.yaxis.set_major_locator(ticker.MultipleLocator(0.5))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax.text(1.8, 0.5, "MultipleLocator(0.5)", fontsize=14, rotation=90, \
        transform=ax.transAxes,va='center')

# Fixed Locator
ax = plt.subplot(1, n, 3)
setup(ax)
majors = [0, 1, 5]
ax.yaxis.set_major_locator(ticker.FixedLocator(majors))
minors = np.linspace(0, 1, 11)[1:-1]
ax.yaxis.set_minor_locator(ticker.FixedLocator(minors))
ax.text(1.8, 0.5, "FixedLocator([0, 1, 5])", fontsize=14, rotation=90, \
        transform=ax.transAxes,va='center')

# Linear Locator
ax = plt.subplot(1, n, 4)
setup(ax)
ax.yaxis.set_major_locator(ticker.LinearLocator(3))
ax.yaxis.set_minor_locator(ticker.LinearLocator(31))
ax.text(1.8, 0.5, "LinearLocator(numticks=3)", rotation=90, \
        fontsize=14, transform=ax.transAxes,va='center')

# Index Locator
ax = plt.subplot(1, n, 5)
setup(ax)
ax.plot(range(0, 5), [0]*5, color='White')
ax.yaxis.set_major_locator(ticker.IndexLocator(base=.5, offset=.25))
ax.text(1.8, 0.5, "IndexLocator(base=0.5, offset=0.25)",  rotation=90, \
        fontsize=14, transform=ax.transAxes,va='center')

# Auto Locator
ax = plt.subplot(1, n, 6)
setup(ax)
ax.yaxis.set_major_locator(ticker.AutoLocator())
ax.yaxis.set_minor_locator(ticker.AutoMinorLocator())
ax.text(1.8, 0.5, "AutoLocator()", fontsize=14, transform=ax.transAxes, rotation=90,va='center')

# MaxN Locator
ax = plt.subplot(1, n, 7)
setup(ax)
ax.yaxis.set_major_locator(ticker.MaxNLocator(4))
ax.yaxis.set_minor_locator(ticker.MaxNLocator(40))
ax.text(1.8, 0.5, "MaxNLocator(n=4)", fontsize=14, transform=ax.transAxes, rotation=90,va='center')

# Log Locator
ax = plt.subplot(1, n, 8)
setup(ax)
ax.set_ylim(10**3, 10**10)
ax.set_yscale('log')
ax.yaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=15))
ax.text(1.8, 0.5, "LogLocator(base=10, numticks=15)",rotation=90, \
        fontsize=15, transform=ax.transAxes, va='center')

# Push the top of the top axes outside the figure because we only show the
# bottom spine.
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.05, top=1.05)

# %% [markdown]
# # Color Maps

# %%
from __future__ import division

import matplotlib.pyplot as plt
from matplotlib import colors as mcolors


colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)

# Sort colors by hue, saturation, value and name.
by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgba(color)[:3])), name)
                for name, color in colors.items())
sorted_names = [name for hsv, name in by_hsv]

n = len(sorted_names)
ncols = 4
nrows = n // ncols + 1

fig, ax = plt.subplots(figsize=(8, 5))

# Get height and width
X, Y = fig.get_dpi() * fig.get_size_inches()
h = Y / (nrows + 1)
w = X / ncols

for i, name in enumerate(sorted_names):
    col = i % ncols
    row = i // ncols
    y = Y - (row * h) - h

    xi_line = w * (col + 0.05)
    xf_line = w * (col + 0.25)
    xi_text = w * (col + 0.3)

    ax.text(xi_text, y, name, fontsize=(h * 0.8),
            horizontalalignment='left',
            verticalalignment='center')

    ax.hlines(y + h * 0.1, xi_line, xf_line,
              color=colors[name], linewidth=(h * 0.6))

ax.set_xlim(0, X)
ax.set_ylim(0, Y)
ax.set_axis_off()

fig.subplots_adjust(left=0, right=1,
                    top=1, bottom=0,
                    hspace=0, wspace=0)
plt.show()

# %% [markdown]
# # Handle a NAN values in the plot

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0.0, 1.0 + 0.01, 0.01)
s = np.cos(2 * 2*np.pi * t)
t[41:60] = np.nan

plt.subplot(2, 1, 1)
plt.plot(t, s, '-', lw=2)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('A sine wave with a gap of NaNs between 0.4 and 0.6')
plt.grid(True)

plt.subplot(2, 1, 2)
t[0] = np.nan
t[-1] = np.nan
plt.plot(t, s, '-', lw=2)
plt.title('Also with NaN in first and last point')

plt.xlabel('time (s)')
plt.ylabel('more nans')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot with masked data

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2*np.pi, 0.02)
y = np.sin(x)
y1 = np.sin(2*x)
y2 = np.sin(3*x)
ym1 = np.ma.masked_where(y1 > 0.5, y1)
ym2 = np.ma.masked_where(y2 < -0.5, y2)

lines = plt.plot(x, y, x, ym1, x, ym2, 'o')
plt.setp(lines[0], linewidth=4)
plt.setp(lines[1], linewidth=2)
plt.setp(lines[2], markersize=10)

plt.legend(('No mask', 'Masked if > 0.5', 'Masked if < -0.5'),
           loc='upper right')
plt.title('Masked line demo')
plt.show()

# %% [markdown]
# # Stack Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y1 = [1, 1, 2, 3, 5]
y2 = [0, 4, 2, 6, 8]
y3 = [1, 3, 5, 7, 9]

y = np.vstack([y1, y2, y3])

labels = ["Fibonacci ", "Evens", "Odds"]

fig, ax = plt.subplots()
ax.stackplot(x, y1, y2, y3, labels=labels)
ax.legend(loc=2)
plt.show()

fig, ax = plt.subplots()
ax.stackplot(x, y)
plt.show()

# %% [markdown]
# # Color by y-value

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2 * np.pi * t)

upper = 0.77
lower = -0.77


supper = np.ma.masked_where(s < upper, s)
slower = np.ma.masked_where(s > lower, s)
smiddle = np.ma.masked_where(np.logical_or(s < lower, s > upper), s)

fig, ax = plt.subplots()
ax.plot(t, smiddle, t, slower, t, supper)
plt.show()

# %%
print(supper)
# Out:
# [-- -- -- -- -- -- -- -- -- -- -- -- -- -- 0.7705132427757893
#  0.8090169943749473 0.8443279255020151 0.8763066800438637
#  0.9048270524660196 0.9297764858882513 0.9510565162951535
#  0.9685831611286311 0.9822872507286886 0.9921147013144779
#  0.9980267284282716 1.0 0.9980267284282716 0.9921147013144778
#  0.9822872507286886 0.9685831611286312 0.9510565162951536
#  0.9297764858882513 0.9048270524660195 0.8763066800438635
#  0.844327925502015 0.8090169943749475 0.7705132427757893 -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  0.7705132427757893 0.8090169943749478 0.8443279255020147
#  0.8763066800438631 0.9048270524660194 0.9297764858882511
#  0.9510565162951534 0.968583161128631 0.9822872507286886
#  0.9921147013144778 0.9980267284282716 1.0 0.9980267284282716
#  0.9921147013144779 0.9822872507286886 0.9685831611286311
#  0.9510565162951536 0.9297764858882517 0.9048270524660192
#  0.8763066800438635 0.8443279255020151 0.8090169943749477
#  0.7705132427757886 -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --
#  -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- -- --]

# %% [markdown]
# # Picking the line color from colormap and drowing with colorbar

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cmx
import matplotlib.colors as colors
import numpy as np
# %matplotlib inline

x = np.arange(100)
nlines = 10
y = np.zeros((nlines,len(x)),dtype=np.float32)
for i in range(nlines):
    y[i] = x**2+i*10
    

fig,ax = plt.subplots()

# choose the colormap and scaled it
cmap = cmx.jet
lcolor = cmap(np.linspace(0,1,nlines))

for i in range(nlines):
    ax.loglog(x,y[i],color=lcolor[i])

# Draw color bar
norm = colors.Normalize(vmin=0, vmax=nlines)
s_map = cmx.ScalarMappable(norm=norm, cmap=cmap)
s_map.set_array(range(nlines))
fig.colorbar(s_map,ax=ax,label='line number')

# %% [markdown]
# # Animation

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib import animation

# if ffmpeg is not in the global environment
#plt.rcParams['animation.ffmpeg_path'] = 'C:\\Users\\astrodoo\\ffmpeg-20190711-af9dc02-win64-static\\bin\\ffmpeg.exe'

fig, ax = plt.subplots()
xdata, ydata = [], []
ln, = plt.plot([], [], 'ro')

def init():
    ax.set_xlim(0, 2*np.pi)
    ax.set_ylim(-1, 1)
    return ln,

def update(frame):
    xdata.append(frame)
    ydata.append(np.sin(frame))
    ln.set_data(xdata, ydata)
    return ln,

ani = FuncAnimation(fig, update, frames=np.linspace(0, 2*np.pi, 128),
                    init_func=init, blit=True)

FFwriter = animation.FFMpegWriter(fps=24)
ani.save('../movie/movie_tmp.mp4', writer = FFwriter, dpi=100)

# %%
""" read image files to be combined """
import os
import numpy as np

imgdir = '../data/movie_figures'
allfiles = os.listdir(imgdir)
imgfiles = [file for file in allfiles if ('.png' in file)]

#print(imgfiles)
imgfiles_wpath = [os.path.join(imgdir,imgf) for imgf in imgfiles]  # image file with directory

print(imgfiles_wpath)
# Out:
# ['../data/movie_figures/frame030.png', '../data/movie_figures/frame024.png', '../data/movie_figures/frame018.png', '../data/movie_figures/frame019.png', '../data/movie_figures/frame025.png', '../data/movie_figures/frame031.png', '../data/movie_figures/frame027.png', '../data/movie_figures/frame033.png', '../data/movie_figures/frame032.png', '../data/movie_figures/frame026.png', '../data/movie_figures/frame022.png', '../data/movie_figures/frame036.png', '../data/movie_figures/frame037.png', '../data/movie_figures/frame023.png', '../data/movie_figures/frame009.png', '../data/movie_figures/frame035.png', '../data/movie_figures/frame021.png', '../data/movie_figures/frame020.png', '../data/movie_figures/frame034.png', '../data/movie_figures/frame008.png', '../data/movie_figures/frame053.png', '../data/movie_figures/frame047.png', '../data/movie_figures/frame090.png', '../data/movie_figures/frame084.png', '../data/movie_figures/frame085.png', '../data/movie_figures/frame091.png', '../data/movie_figures/frame046.png', '../data/movie_figures/frame052.png', '../data/movie_figures/frame044.png', '../data/movie_figures/frame050.png', '../data/movie_figures/frame078.png', '../data/movie_figures/frame087.png', '../data/movie_figures/frame093.png', '../data/movie_figures/frame092.png', '../data/movie_figures/frame086.png', '../data/movie_figures/frame079.png', '../data/movie_figures/frame051.png', '../data/movie_figures/frame045.png', '../data/movie_figures/frame069.png', '../data/movie_figures/frame041.png', '../data/movie_figures/frame055.png', '../data/movie_figures/frame082.png', '../data/movie_figures/frame096.png', '../data/movie_figures/frame097.png', '../data/movie_figures/frame083.png', '../data/movie_figures/frame054.png', '../data/movie_figures/frame040.png', '../data/movie_figures/frame068.png', '../data/movie_figures/frame056.png', '../data/movie_figures/frame042.png', '../data/movie_figures/frame095.png', '../data/movie_figures/frame081.png', '../data/movie_figures/frame080.png', '../data/movie_figures/frame094.png', '../data/movie_figures/frame043.png', '../data/movie_figures/frame057.png', '../data/movie_figures/frame072.png', '../data/movie_figures/frame066.png', '../data/movie_figures/frame099.png', '../data/movie_figures/frame098.png', '../data/movie_figures/frame067.png', '../data/movie_figures/frame073.png', '../data/movie_figures/frame065.png', '../data/movie_figures/frame071.png', '../data/movie_figures/frame059.png', '../data/movie_figures/frame058.png', '../data/movie_figures/frame070.png', '../data/movie_figures/frame064.png', '../data/movie_figures/frame048.png', '../data/movie_figures/frame060.png', '../data/movie_figures/frame074.png', '../data/movie_figures/frame100.png', '../data/movie_figures/frame075.png', '../data/movie_figures/frame061.png', '../data/movie_figures/frame049.png', '../data/movie_figures/frame077.png', '../data/movie_figures/frame063.png', '../data/movie_figures/frame088.png', '../data/movie_figures/frame089.png', '../data/movie_figures/frame062.png', '../data/movie_figures/frame076.png', '../data/movie_figures/frame011.png', '../data/movie_figures/frame005.png', '../data/movie_figures/frame039.png', '../data/movie_figures/frame038.png', '../data/movie_figures/frame004.png', '../data/movie_figures/frame010.png', '../data/movie_figures/frame006.png', '../data/movie_figures/frame012.png', '../data/movie_figures/frame013.png', '../data/movie_figures/frame007.png', '../data/movie_figures/frame003.png', '../data/movie_figures/frame017.png', '../data/movie_figures/frame016.png', '../data/movie_figures/frame002.png', '../data/movie_figures/frame028.png', '../data/movie_figures/frame014.png', '../data/movie_figures/frame000.png', '../data/movie_figures/frame001.png', '../data/movie_figures/frame015.png', '../data/movie_figures/frame029.png']

# %%
def animate_from_image(filelist,out='movie_torus.mp4'):
    import numpy as np
    import matplotlib.image as image
    from matplotlib import pyplot as plt
    from matplotlib import animation
    
    # if ffmpeg is not in the global environment
    #plt.rcParams['animation.ffmpeg_path'] = 'C:\\Users\\astrodoo\\ffmpeg-20190711-af9dc02-win64-static\\bin\\ffmpeg.exe'

    img = image.imread(filelist[0])
    
    dpi = 100
    height, width, depth = img.shape

    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)
    
    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    #ax.imshow(img,interpolation='spline16',vmin=0,vmax=1.)

    #res=1
    def init():
        res = ax.imshow(img,interpolation='spline16',animated=True,vmin=0.,vmax=1.)
        return res,

    def animate(flist):
        img = image.imread(flist)       
        res = ax.imshow(img,interpolation='spline16',animated=True,vmin=0.,vmax=1.)
        print('Insert %s to the movie (last snapshot:%s)'%(flist,filelist[-1]))
        return res,
    
    anim = animation.FuncAnimation(fig, animate, init_func=init, frames=filelist, interval=25, blit=True, repeat=False)
    #anim = animation.FuncAnimation(fig, animate, frames=filelist, interval=25, blit=True, repeat=False)
    FFwriter = animation.FFMpegWriter(fps=10)
    anim.save(out, writer = FFwriter, dpi=100)
    
    plt.close()

# %%
animate_from_image(imgfiles_wpath,out='../movie/movie_sample.mp4')
# Out:
# Insert ../data/movie_figures/frame030.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame024.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame018.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame019.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame025.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame031.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame027.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame033.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame032.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame026.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame022.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame036.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame037.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame023.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame009.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame035.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame021.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame020.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame034.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame008.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame053.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame047.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame090.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame084.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame085.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame091.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame046.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame052.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame044.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame050.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame078.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame087.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame093.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame092.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame086.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame079.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame051.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame045.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame069.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame041.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame055.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame082.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame096.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame097.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame083.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame054.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame040.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame068.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame056.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame042.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame095.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame081.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame080.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame094.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame043.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame057.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame072.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame066.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame099.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame098.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame067.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame073.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame065.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame071.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame059.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame058.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame070.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame064.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame048.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame060.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame074.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame100.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame075.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame061.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame049.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame077.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame063.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame088.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame089.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame062.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame076.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame011.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame005.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame039.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame038.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame004.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame010.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame006.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame012.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame013.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame007.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame003.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame017.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame016.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame002.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame028.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame014.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame000.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame001.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame015.png to the movie (last snapshot:../data/movie_figures/frame029.png)
# Insert ../data/movie_figures/frame029.png to the movie (last snapshot:../data/movie_figures/frame029.png)

# %% [markdown]
# # Streamplot

# %%
xx = np.array([[-32.77352506, -32.50517324, -32.30341846, -32.12060867, -31.99103968],
   [-32.88670112, -32.63078693, -32.42892793, -32.2527705 , -32.11911059],
   [-32.99884749, -32.75419286, -32.55377179, -32.38220417,-32.24664094],
   [-33.10888993, -32.87495033, -32.67707405, -32.50885765,-32.37311971],
   [-33.2179889 , -32.99317728, -32.79848554, -32.63304009,-32.49815164],
   [-33.32651265, -33.10917094, -32.91791567, -32.75496914,-32.62146004],
   [-33.43449219, -33.22321261, -33.03537769, -32.87477271,-32.74286757],
   [-33.54184645, -33.33551502, -33.15092328, -32.99252837,-32.86227065],
   [-33.64847256, -33.44622558, -33.26461466, -33.1082882 ,-32.97961644],
   [-33.7542787 , -33.55544297, -33.37651245, -33.22209182,-33.09488502],
   [-33.85919362, -33.66323316, -33.48667092, -33.33397251,-33.20807667],
   [-33.96316738, -33.76964127, -33.59513666, -33.44395994,-33.31920308],
   [-34.06616899, -33.87469962, -33.70194888, -33.55208114,-33.42828168],
   [-34.16818354, -33.97843289, -33.80714029, -33.6583608 , -33.5353318 ],
   [-34.26920936, -34.08086103, -33.91073804, -33.76282129,-33.64037232],
   [-34.36925566, -34.18200076, -34.01276449, -33.86548266,-33.74342012],
   [-34.46834041, -34.28186594, -34.11323791, -33.96636282,-33.84448915],
   [-34.56648851, -34.38046701, -34.21217281, -34.06547784,-33.94358994],
   [-34.66372971, -34.4778096 , -34.30958029, -34.16284263, -34.0407292 ],
   [-34.76009619, -34.57389229, -34.40546833, -34.2584719 ,-34.13590974],
   [-34.85561889, -34.66870332, -34.49984222, -34.35238178,-34.22913045],
   [-34.95032165, -34.76221629, -34.59270529, -34.44459209,-34.32038648],
   [-35.04421102, -34.85438466, -34.6840602 , -34.5351297 ,-34.40966975],
   [-35.13725786, -34.94513595, -34.77391107, -34.62403315,-34.49697031],
   [-35.22936336, -35.03436723, -34.86226647, -34.7113589 , -34.5822793 ],
   [-35.3202956 , -35.12194712, -34.9491432 , -34.79718943,-34.66559567],
   [-35.40957149, -35.20773648, -35.03457067, -34.88164276,-34.74693998],
   [-35.49624617, -35.29165455, -35.11859869, -34.96488179,-34.82637986],
   [-35.57858891, -35.3738341 , -35.20134195, -35.04711944,-34.90406862],
   [-35.65407127, -35.45484625, -35.28327484, -35.12861303,-34.98028311]])


yy = np.array([[-11.3529916 , -10.83017948, -10.36062676,  -9.85499224,-9.36742115],
   [-11.24914312, -10.77486528, -10.30767657,  -9.81790781,-9.33347811],
   [-11.16896123, -10.71827884, -10.25654788,  -9.77873607,-9.29985941],
   [-11.09864806, -10.66157581, -10.20688907,  -9.7389486 ,-9.26669158],
   [-11.03379175, -10.60554773, -10.15836065,  -9.69919353,  -9.2340536 ],
   [-10.97234269, -10.55056628, -10.11076275,  -9.65973621,-9.20197376],
   [-10.91318741, -10.49672964, -10.06398502,  -9.62068888,-9.17044015],
   [-10.85567682, -10.44399733, -10.01795592,  -9.58209354,-9.13941538],
   [-10.79941292, -10.39227109,  -9.97261586,  -9.54395471,-9.10884902],
   [-10.74413933, -10.3414354 ,  -9.92790608,  -9.50625469,-9.07868586],
   [-10.68968138, -10.29137538,  -9.88376528,  -9.46896173,-9.04887037],
   [-10.63591212, -10.24198327,  -9.84012944,  -9.43203502,-9.01934878],
   [-10.58273238, -10.19315956,  -9.79693259,  -9.39542787,-8.99006955],
   [-10.53005851, -10.14481189,  -9.75410767,  -9.35908973,-8.96098324],
   [-10.47781454, -10.09685326,  -9.71158727,  -9.32296761,-8.93204187],
   [-10.42592671, -10.04920008,  -9.66930413,  -9.28700687,-8.90319822],
   [-10.37431922, -10.00177041,  -9.62719161,  -9.25115173,  -8.874405  ],
   [-10.32291042,  -9.95448254,  -9.5851842 ,  -9.21534553,-8.84561388],
   [-10.27160885,  -9.90725399,  -9.54321824,  -9.17953081,  -8.8167744 ],
   [-10.22030865,  -9.86000117,  -9.50123304,  -9.1436493 ,-8.78783251],
   [-10.16888358,  -9.81263985,  -9.45917264,  -9.10764179,-8.75872859],
   [-10.11717908,  -9.7650871 ,  -9.41698825,  -9.07144794,-8.72939466],
   [-10.06500151,  -9.71726547,  -9.37464171,  -9.03500603,-8.69975035],
   [-10.01210356,  -9.66911062,  -9.33211024,  -8.99825263,-8.66969694],
   [ -9.95816574,  -9.62058406,  -9.28939255,  -8.96112225,  -8.639109  ],
   [ -9.90277604,  -9.57169217,  -9.24651752,  -8.92354679,-8.60782312],
   [ -9.84541584,  -9.52250952,  -9.2035585 ,  -8.88545441,-8.57562469],
   [ -9.78546516,  -9.4731919 ,  -9.1606645 ,  -8.84676681,-8.54223813],
   [ -9.72217224,  -9.42392909,  -9.11814094,  -8.80739381,-8.50733329],
   [ -9.65407127,  -9.37474785,  -9.07654968,  -8.76722606,-8.47056622]])

u = 1/2*np.sin(xx)*-3*np.cos(yy**2)
v = 2*np.sin(xx)*3*np.cos(yy)
speed = np.sqrt((u**2)+(v**2))

# %%
from scipy.interpolate import griddata

def streams(ax,xx,yy,u,v,base_map=False):
 x = np.linspace(xx.min(), xx.max(), 50)
 y = np.linspace(yy.min(), yy.max(), 50)

 xi, yi = np.meshgrid(x,y)

 #then, interpolate your data onto this grid:

 px = xx.flatten()
 py = yy.flatten()
 pu = u.flatten()
 pv = v.flatten()
 pspeed = speed.flatten()

 gu = griddata((px,py), pu, (xi,yi))
 gv = griddata((px,py), pv, (xi,yi))
 gspeed = griddata((px,py), pspeed, (xi,yi))

 lw = 6*gspeed/np.nanmax(gspeed)
 #now, you can use x, y, gu, gv and gspeed in streamplot:

 if base_map:
    xx,yy = ax(xx,yy)
    xi,yi = ax(xi,yi)

 ax.contour(xx,yy,speed, colors='k', alpha=0.4)
 ax.plot(xx,yy,'-k',alpha=0.3)
 ax.plot(xx.T,yy.T,'-k',alpha=0.3)
 ax.plot(xi,yi,'-b',alpha=0.1)
 ax.plot(xi.T,yi.T,'-b',alpha=0.1)
 c = ax.streamplot(x,y,gu,gv, density=2,
    linewidth=lw, color=gspeed, cmap=plt.cm.jet)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig,ax = plt.subplots()

streams(ax,xx,yy,u,v,base_map=False)
