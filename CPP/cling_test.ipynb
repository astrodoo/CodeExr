// %%
#include <iostream>

std::cout << "hey!!" << std::endl;
// Out:
// input_line_18:2:26: error: reference to overloaded function could not be resolved; did you mean to call it?
//  std::cout << "hey!!" << std::endl;
//                          ^~~~~~~~~
// /Users/astrodoo/anaconda2/envs/cling/include/c++/v1/ostream:999:1: note: possible target for call
// endl(basic_ostream<_CharT, _Traits>& __os)
// ^
// /Users/astrodoo/anaconda2/envs/cling/include/c++/v1/ostream:218:20: note: candidate function not viable: no overload of 'endl' matching 'const void *' for
//       1st argument
//     basic_ostream& operator<<(const void* __p);
//                    ^
// /Users/astrodoo/anaconda2/envs/cling/include/c++/v1/ostream:198:20: note: candidate function not viable: no overload of 'endl' matching
//       'basic_ios<std::__1::basic_ostream<char, std::__1::char_traits<char>
//       >::char_type, std::__1::basic_ostream<char, std::__1::char_traits<char>
//       >::traits_type> &(*)(basic_ios<std::__1::basic_ostream<char,
// ...

// %%
int main(int argc, char* argv[])
{
    USERDATA user = {10, "hey"};

    user.Print();

    return 0;
}

// %%
main();
// Out:
// input_line_14:2:2: error: no matching function for call to 'main'
//  main();
//  ^~~~
// input_line_13:1:5: note: candidate function not viable: requires 2 arguments, but 0 were provided
// int main(int argc, char* argv[])
//     ^
// Interpreter Error:
